# %% [markdown]
# # Experimenting with Complex Networks Minimum Spanning Trees

# %%
import networkx as nx
import snap
import matplotlib.pyplot as plt

# %% [markdown]
# ## Small World Graphs

# %% [markdown]
# A small-world network refers to an ensemble of networks in which the mean geodesic (i.e., shortest-path) distance between nodes increases sufficiently slowly as a function of the number of nodes in the network (http://www.scholarpedia.org/article/Small-world_network). <br>
# The Watts–Strogatz model is a random graph generation model that produces graphs with small-world properties, including short average path lengths and high clustering. We use Watts-Strogatz generation for the following experiments. <br>
# NetworkX (https://networkx.org/documentation/networkx-1.9/reference/generated/networkx.generators.random_graphs.watts_strogatz_graph.html) has a function 'watts_strogatz_graph' that returns a Watts-Strogatz small-world graph. The input parameters are n (the number of nodes), k (each node is connected to k nearest neighbors in ring topology), and p (probability of rewiring each edge). <br>
# Here is a brief description of the Watts-Strogatz algorithm: First create a ring over $n$ nodes. Then each node in the ring is joined to its 𝑘 nearest neighbors (or $k$−1 neighbors if $k$ is odd). Then shortcuts are created by replacing some edges as follows: for each edge ($u$,$v$) in the underlying “$n$-ring with $k$ nearest neighbors” with probability $p$ replace it with a new edge ($u$,$w$) with uniformly random choice of existing node $w$.

# %%
sw = nx.generators.random_graphs.watts_strogatz_graph(20, 20, 0.1)
nx.draw(sw)

# %% [markdown]
# ### Experiment 1
# How does changing clustering by changing the initial clustering $k$ affect the efficiency of the MST of a small world graph, with different probabilities of rewiring in the generation process?
# PS: Changing of clustering was also tested with differently sized graphs. The results were similar, so I have recorded only the case with 20 nodes for ease.

# %%
x1 = []
y1 = []
for i in range(2, 21):
    x1.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(20, i, 0.1)
    mst = nx.minimum_spanning_tree(sw)
    y1.append(nx.global_efficiency(mst))
x2 = []
y2 = []
for i in range(2, 21):
    x2.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(20, i, 0.2)
    mst = nx.minimum_spanning_tree(sw)
    y2.append(nx.global_efficiency(mst))
x3 = []
y3 = []
for i in range(2, 21):
    x3.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(20, i, 0.3)
    mst = nx.minimum_spanning_tree(sw)
    y3.append(nx.global_efficiency(mst))
x4 = []
y4 = []
for i in range(2, 21):
    x4.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(20, i, 0.4)
    mst = nx.minimum_spanning_tree(sw)
    y4.append(nx.global_efficiency(mst))
x5 = []
y5 = []
for i in range(2, 21):
    x5.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(20, i, 0.5)
    mst = nx.minimum_spanning_tree(sw)
    y5.append(nx.global_efficiency(mst))
x6 = []
y6 = []
for i in range(2, 21):
    x6.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(20, i, 0.6)
    mst = nx.minimum_spanning_tree(sw)
    y6.append(nx.global_efficiency(mst))
x7 = []
y7 = []
for i in range(2, 21):
    x7.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(20, i, 0.7)
    mst = nx.minimum_spanning_tree(sw)
    y7.append(nx.global_efficiency(mst))
x8 = []
y8 = []
for i in range(2, 21):
    x8.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(20, i, 0.8)
    mst = nx.minimum_spanning_tree(sw)
    y8.append(nx.global_efficiency(mst))
x9 = []
y9 = []
for i in range(2, 21):
    x2.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(20, i, 0.9)
    mst = nx.minimum_spanning_tree(sw)
    y2.append(nx.global_efficiency(mst))

# %%
g1, = plt.plot(x1,y1)
g2, = plt.plot(x2,y2)
g3, = plt.plot(x3,y3)
g4, = plt.plot(x4,y4)
g5, = plt.plot(x5,y5)
g6, = plt.plot(x6,y6)
g7, = plt.plot(x7,y7)
g8, = plt.plot(x8,y8)
g9, = plt.plot(x9,y9)
plt.legend([g1, g2, g3, g4, g5, g6, g7, g8, g9], ('p=0.1','p=0.2','p=0.3','p=0.4','p=0.5','p=0.6','p=0.7','p=0.8','p=0.9'))

# %% [markdown]
# From the graph above, it seems that the actual probability of rewiring does not affect the efficiency of the minimum spanning tree of the small-world graph. However, we see that increasing clustering increases the efficiency of the small-world graph minimum spanning tree. This seems intuitive enough. However, I imagine that when robustness is measured, robustness will decrease as clustering increases (https://www.nature.com/articles/srep37317).

# %% [markdown]
# ### Experiment 2
# How does the number of nodes in a small-world graph affect the efficiency of the minimum spanning tree for different levels of clustering?

# %%
x1 = []
y1 = []
for i in range(2, 20):
    x1.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(i, 2, 0.5)
    mst = nx.minimum_spanning_tree(sw)
    y1.append(nx.global_efficiency(mst))
x2 = []
y2 = []
for i in range(3, 20):
    x2.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(i, 3, 0.5)
    mst = nx.minimum_spanning_tree(sw)
    y2.append(nx.global_efficiency(mst))
x3 = []
y3 = []
for i in range(4, 20):
    x3.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(i, 4, 0.5)
    mst = nx.minimum_spanning_tree(sw)
    y3.append(nx.global_efficiency(mst))
x4 = []
y4 = []
for i in range(5, 20):
    x4.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(i, 5, 0.4)
    mst = nx.minimum_spanning_tree(sw)
    y4.append(nx.global_efficiency(mst))
x5 = []
y5 = []
for i in range(6, 20):
    x5.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(i, 6, 0.5)
    mst = nx.minimum_spanning_tree(sw)
    y5.append(nx.global_efficiency(mst))
x6 = []
y6 = []
for i in range(7, 20):
    x6.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(i, 7, 0.5)
    mst = nx.minimum_spanning_tree(sw)
    y6.append(nx.global_efficiency(mst))
x7 = []
y7 = []
for i in range(8, 20):
    x7.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(i, 8, 0.5)
    mst = nx.minimum_spanning_tree(sw)
    y7.append(nx.global_efficiency(mst))
x8 = []
y8 = []
for i in range(9, 20):
    x8.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(i, 9, 0.5)
    mst = nx.minimum_spanning_tree(sw)
    y8.append(nx.global_efficiency(mst))
x9 = []
y9 = []
for i in range(10, 20):
    x9.append(i)
    sw = nx.generators.random_graphs.watts_strogatz_graph(i, 10, 0.5)
    mst = nx.minimum_spanning_tree(sw)
    y9.append(nx.global_efficiency(mst))

# %%
g1, = plt.plot(x1,y1)
g2, = plt.plot(x2,y2)
g3, = plt.plot(x3,y3)
g4, = plt.plot(x4,y4)
g5, = plt.plot(x5,y5)
g6, = plt.plot(x6,y6)
g7, = plt.plot(x7,y7)
g8, = plt.plot(x8,y8)
g9, = plt.plot(x9,y9)
plt.legend([g1, g2, g3, g4, g5, g6, g7, g8, g9], ('k=2','k=3','k=4','k=5','k=6','k=7','k=8','k=9','k=10'))

# %% [markdown]
# It makes sense that efficiency reduces as the graph size increases, since this probably results in increases in the average global efficiency because path lengths can become longer as the graph size increases. While the same trend is followed by graph sizes at all levels of clustering, we see again that increasing clustering increases the global efficiency of the graph. This carries over to the minimum spanning trees.

# %% [markdown]
# ## Scale-Free Graphs

# %% [markdown]
# Generally a network is deemed scale free if the fraction of nodes with degree $k$ follows a power-law distribution $k^{-\alpha}$, where $\alpha < 1$.

# %% [markdown]
# ### Barabási-Albert Graph
# A graph of $n$ nodes is grown by attaching new nodes each with $m$ edges that are preferentially attached to existing nodes with high degree.

# %%
sf = nx.generators.random_graphs.barabasi_albert_graph(20,1)
nx.draw(sf)

# %% [markdown]
# #### Experiment 1
# How does the efficiency of the minimum spanning tree of a Barabási-Albert graph change with an increase in $m$ as the number of nodes $n$ stays constant?

# %%
x1 = []
y1 = []
for i in range(1, 50):
    x1.append(i)
    sw = nx.generators.random_graphs.barabasi_albert_graph(50, i)
    mst = nx.minimum_spanning_tree(sw)
    y1.append(nx.global_efficiency(mst))
plt.plot(x1, y1)

# %% [markdown]
# The efficiency of the minimum spanning trees of the graphs increases as the value of $m$ increases.

# %% [markdown]
# #### Experiment 2
# How does the efficiency of the minimum spanning tree of a Barabási-Albert graph change with an increase in $n$ (as the graph grows larger)?

# %%
x1 = []
y1 = []
for i in range(2, 20):
    x1.append(i)
    sw = nx.generators.random_graphs.barabasi_albert_graph(i, 1)
    mst = nx.minimum_spanning_tree(sw)
    y1.append(nx.global_efficiency(mst))
x2 = []
y2 = []
for i in range(3, 20):
    x2.append(i)
    sw = nx.generators.random_graphs.barabasi_albert_graph(i, 2)
    mst = nx.minimum_spanning_tree(sw)
    y2.append(nx.global_efficiency(mst))
x3 = []
y3 = []
for i in range(4, 20):
    x3.append(i)
    sw = nx.generators.random_graphs.barabasi_albert_graph(i, 3)
    mst = nx.minimum_spanning_tree(sw)
    y3.append(nx.global_efficiency(mst))
x4 = []
y4 = []
for i in range(5, 20):
    x4.append(i)
    sw = nx.generators.random_graphs.barabasi_albert_graph(i, 4)
    mst = nx.minimum_spanning_tree(sw)
    y4.append(nx.global_efficiency(mst))
x5 = []
y5 = []
for i in range(6, 20):
    x5.append(i)
    sw = nx.generators.random_graphs.barabasi_albert_graph(i, 5)
    mst = nx.minimum_spanning_tree(sw)
    y5.append(nx.global_efficiency(mst))
x6 = []
y6 = []
for i in range(7, 20):
    x6.append(i)
    sw = nx.generators.random_graphs.barabasi_albert_graph(i, 6)
    mst = nx.minimum_spanning_tree(sw)
    y6.append(nx.global_efficiency(mst))
x7 = []
y7 = []
for i in range(8, 20):
    x7.append(i)
    sw = nx.generators.random_graphs.barabasi_albert_graph(i, 7)
    mst = nx.minimum_spanning_tree(sw)
    y7.append(nx.global_efficiency(mst))
x8 = []
y8 = []
for i in range(9, 20):
    x8.append(i)
    sw = nx.generators.random_graphs.barabasi_albert_graph(i, 8)
    mst = nx.minimum_spanning_tree(sw)
    y8.append(nx.global_efficiency(mst))
x9 = []
y9 = []
for i in range(10, 20):
    x9.append(i)
    sw = nx.generators.random_graphs.barabasi_albert_graph(i, 9)
    mst = nx.minimum_spanning_tree(sw)
    y9.append(nx.global_efficiency(mst))

# %%
g1, = plt.plot(x1,y1)
g2, = plt.plot(x2,y2)
g3, = plt.plot(x3,y3)
g4, = plt.plot(x4,y4)
g5, = plt.plot(x5,y5)
g6, = plt.plot(x6,y6)
g7, = plt.plot(x7,y7)
g8, = plt.plot(x8,y8)
g9, = plt.plot(x9,y9)
plt.legend([g1, g2, g3, g4, g5, g6, g7, g8, g9], ('m=1','m=2','m=3','m=4','m=5','m=6','m=7','m=8','m=9'))

# %% [markdown]
# The efficiency of the MST of the graphs grows smaller as the number of nodes increases. As expected from the previous experiment, we see increases in efficiency with increases in m.

# %% [markdown]
# ## Erdós-Rényi Graphs

# %%
er = nx.generators.random_graphs.erdos_renyi_graph(5,0.5)
nx.draw(er)

# %% [markdown]
# ### Experiment
# How does the efficiency of the minimum spanning tree change as the size of an ER graph changes, as well as the p-value?

# %%
x1 = []
y1 = []
for i in range(2, 101):
    x1.append(i)
    er = nx.generators.random_graphs.erdos_renyi_graph(i,0.1)
    mst = nx.minimum_spanning_tree(er)
    y1.append(nx.global_efficiency(mst))
x2 = []
y2 = []
for i in range(2, 101):
    x2.append(i)
    er = nx.generators.random_graphs.erdos_renyi_graph(i,0.2)
    mst = nx.minimum_spanning_tree(er)    
    y2.append(nx.global_efficiency(mst))
x3 = []
y3 = []
for i in range(2, 101):
    x3.append(i)
    er = nx.generators.random_graphs.erdos_renyi_graph(i,0.3)
    mst = nx.minimum_spanning_tree(er)
    y3.append(nx.global_efficiency(mst))
x4 = []
y4 = []
for i in range(2, 101):
    x4.append(i)
    er = nx.generators.random_graphs.erdos_renyi_graph(i,0.4)
    mst = nx.minimum_spanning_tree(er)
    y4.append(nx.global_efficiency(mst))
x5 = []
y5 = []
for i in range(2, 101):
    x5.append(i)
    er = nx.generators.random_graphs.erdos_renyi_graph(i,0.5)
    mst = nx.minimum_spanning_tree(er)
    y5.append(nx.global_efficiency(mst))
x6 = []
y6 = []
for i in range(2, 101):
    x6.append(i)
    er = nx.generators.random_graphs.erdos_renyi_graph(i,0.6)
    mst = nx.minimum_spanning_tree(er)
    y6.append(nx.global_efficiency(mst))
x7 = []
y7 = []
for i in range(2, 101):
    x7.append(i)
    er = nx.generators.random_graphs.erdos_renyi_graph(i,0.7)
    mst = nx.minimum_spanning_tree(er)
    y7.append(nx.global_efficiency(mst))
x8 = []
y8 = []
for i in range(2, 101):
    x8.append(i)
    er = nx.generators.random_graphs.erdos_renyi_graph(i,0.8)
    mst = nx.minimum_spanning_tree(er)
    y8.append(nx.global_efficiency(mst))
x9 = []
y9 = []
for i in range(2, 101):
    x9.append(i)
    er = nx.generators.random_graphs.erdos_renyi_graph(i,0.9)
    mst = nx.minimum_spanning_tree(er)
    y9.append(nx.global_efficiency(mst))

# %%
g1, = plt.plot(x1,y1)
g2, = plt.plot(x2,y2)
g3, = plt.plot(x3,y3)
g4, = plt.plot(x4,y4)
g5, = plt.plot(x5,y5)
g6, = plt.plot(x6,y6)
g7, = plt.plot(x7,y7)
g8, = plt.plot(x8,y8)
g9, = plt.plot(x9,y9)
plt.legend([g1, g2, g3, g4, g5, g6, g7, g8, g9], ('p=0.1','p=0.2','p=0.3','p=0.4','p=0.5','p=0.6','p=0.7','p=0.8','p=0.9'))

# %% [markdown]
# An increase in p-value increases the efficiency of the minimum spanning trees of ER graphs, but the efficiency seems to stabilize at a particular value per p-value even as the number of nodes in an ER diagram increases.
